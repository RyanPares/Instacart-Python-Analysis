# %% [markdown]
# # Import Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 3. Import orders_products_merge dataframe

# %%
# Set path
path = r'C:\Users\Ryan Pares\Instacart Basket Analysis'

# %%
# Import dataframes ('products.csv' and 'orders_wrangled.csv')
df_prods = pd.read_csv(os.path.join(path, '02 Data' , 'Prepared Data' , 'products_checked.csv'), index_col = False)
orders_products_combined = pd.read_pickle(os.path.join(path, '02 data' , 'prepared data' , 'orders_products_combined.pkl'))

# %% [markdown]
# # 4. Shape of imported dataframe

# %%
# Check shape of the dataframe
orders_products_combined.shape
# Out:
# (32640698, 11)

# %% [markdown]
# # 5. Determining a way to combine orders_products_combined dataframe with  products data set.

# %%
# Check dataframe structure
orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN       196.0                1.0        0.0   both
# 1                     NaN     14084.0                2.0        0.0   both
# 2                     NaN     12427.0                3.0        0.0   both
# 3                     NaN     26088.0                4.0        0.0   both
# 4                     NaN     26405.0                5.0        0.0   both

# %%
# Check the shape
df_prods.shape
# Out:
# (49672, 6)

# %%
# Check dataframe structure

df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#Drop unnamed column in df_prods dataframe
df_prods2 = df_prods.drop('Unnamed: 0', axis=1)

# %%
#Check dataframe structure
df_prods2.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#Check dataframe Shape
df_prods2.shape
# Out:
# (49672, 5)

# %% [markdown]
# # 6. Confirming Merge using Merge Flag

# %%
# Test merge without overwriting with merge flag 'match' using 'product_id' as the key column with an Inner Merge

pd.merge(orders_products_combined , df_prods2 , on = ['product_id'] , how = 'inner', indicator = 'match' )
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32404854   1320836   202557    prior            17          2
# 32404855     31526   202557    prior            18          5
# 32404856    758936   203436    prior             1          2
# 32404857   2745165   203436    prior             2          3
# 32404858   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN       196.0
# 1                         7                    15.0       196.0
# ...

# %%
# actual merge of 'orders_products_combined' and '_df_pords'

ords_prods_merge = orders_products_combined.merge(df_prods2 , on = ['product_id'] , indicator = 'match' )

# %%
# drop the flag column '_merge' from the previous merge

ords_prods_merge.drop('_merge', axis = 1 )
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32404854   1320836   202557    prior            17          2
# 32404855     31526   202557    prior            18          5
# 32404856    758936   203436    prior             1          2
# 32404857   2745165   203436    prior             2          3
# 32404858   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN       196.0
# 1                         7                    15.0       196.0
# ...

# %% [markdown]
# # 7. Export the newly created dataframe as ords_prods_merge

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merge.pkl'))
